# %% [markdown]
# <a href="https://colab.research.google.com/github/JanhaviK30/AIML-B-3rd-year-repo/blob/main/MINI_PROJECT_ZOMATO_DATASET.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#import required libraries and load the dataset
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv("/content/zomato_eda_mini_project.csv")
df.head()
# Out:
#   Restaurant Name     City              Cuisines  Average Cost for two  \
# 0     Ocean Pearl   Mumbai  Seafood, Continental                1450.0
# 1   Pizza Central     Pune        Pizza, Italian                 300.0
# 2      Cafe Aroma     Pune        Cafe, Desserts                 250.0
# 3      Cafe Aroma     Pune        Cafe, Desserts                1850.0
# 4  Bengal Kitchen  Kolkata                   NaN                 150.0
#
#    Price range  Aggregate rating  Votes
# 0            3               3.7  827.0
# 1            1               3.8  415.0
# 2            1               2.7  112.0
# 3            4               4.4  741.0
# 4            1               3.8  635.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 103 entries, 0 to 102
# Data columns (total 7 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Restaurant Name       103 non-null    object
#  1   City                  101 non-null    object
#  2   Cuisines              100 non-null    object
#  3   Average Cost for two  101 non-null    float64
#  4   Price range           103 non-null    int64
#  5   Aggregate rating      101 non-null    float64
#  6   Votes                 102 non-null    float64
# dtypes: float64(3), int64(1), object(3)
# memory usage: 5.8+ KB

# %%
df.isnull().sum()
# Out:
# Restaurant Name         0
# City                    2
# Cuisines                3
# Average Cost for two    2
# Price range             0
# Aggregate rating        2
# Votes                   1
# dtype: int64

# %%
df.drop_duplicates(inplace=True)

df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df["Cuisines"] = df["Cuisines"].fillna("Unknown")
df['Average Cost for two'] = df['Average Cost for two'].fillna(df['Average Cost for two'].median())
df['Rating'] = df['Aggregate rating'].astype(float)


df['Rating'].isnull().sum()


#Visualisation
#chart1: Countplot: Which price range is the most common
plt.figure(figsize=(9,5))

sns.countplot(data=df, x="Price range")

plt.title("Number of Restaurants by Price Range")
plt.xlabel("Price Range")
plt.ylabel("NUmber of Restaurants")
plt.show()

# %%
#Chart2: Which Price range has better ratings
#Bar plot
plt.figure(figsize=(8,7))
sns.barplot(data=df, x="Price range", y="Rating")

plt.title("Restaurants ratings by Price Range")
plt.xlabel("Price Range")
plt.ylabel("Average Ratings")
plt.show()
